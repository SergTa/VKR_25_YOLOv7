# %% [markdown]
# Трекинг всех классов:

# %%
import cv2
from ultralytics import YOLO
import random


def process_video_with_tracking(model, input_video_path, show_video=True, save_video=False, output_video_path="output_video.mp4"):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    if not cap.isOpened():
        raise Exception("Error: Could not open video file.")

    # Get input video frame rate and dimensions
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define the output video writer
    if save_video:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        results = model.track(frame, iou=0.4, conf=0.5, persist=True, imgsz=608, verbose=False, tracker="botsort.yaml")

        if results[0].boxes.id != None: # this will ensure that id is not None -> exist tracks
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            ids = results[0].boxes.id.cpu().numpy().astype(int)

            for box, id in zip(boxes, ids):
                # Generate a random color for each object based on its ID
                random.seed(int(id))
                color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
                
                cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3],), color, 2)
                cv2.putText(
                    frame,
                    f"Id {id}",
                    (box[0], box[1]),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (0, 255, 255),
                    2,
                )
        
        if save_video:
            out.write(frame)

        if show_video:
            frame = cv2.resize(frame, (0, 0), fx=0.75, fy=0.75)
            cv2.imshow("frame", frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    # Release the input video capture and output video writer
    cap.release()
    if save_video:
        out.release()

    # Close all OpenCV windows
    cv2.destroyAllWindows()

# Example usage:
model = YOLO('runs/detect/train/weights/best.pt')
model.fuse()
process_video_with_tracking(model, "./data/VID-20250129-WA0013.mp4", show_video=False, save_video=True, output_video_path="output_video.mp4")
# Out:
# Model summary (fused): 92 layers, 25,844,971 parameters, 0 gradients, 78.7 GFLOPs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 70
#      68 model = YOLO('runs/detect/train/weights/best.pt')
#      69 model.fuse()
# ---> 70 process_video_with_tracking(model, "./data/VID-20250129-WA0013.mp4", show_video=True, save_video=True, output_video_path="output_video.mp4")
#
# Cell In[1], line 27, in process_video_with_tracking(model, input_video_path, show_video, save_video, output_video_path)
#      25 if not ret:
#      26     break
# ---> 27 results = model.track(frame, iou=0.4, conf=0.5, persist=True, imgsz=608, verbose=False, tracker="botsort.yaml")
#      29 if results[0].boxes.id != None: # this will ensure that id is not None -> exist tracks
#      30     boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/engine/model.py:607, in Model.track(self, source, stream, persist, **kwargs)
#     605 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     606 kwargs["mode"] = "track"
# --> 607 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/engine/model.py:560, in Model.predict(self, source, stream, predictor, **kwargs)
#     558 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559     self.predictor.set_prompts(prompts)
# --> 560 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/engine/predictor.py:175, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     173     return self.stream_inference(source, model, *args, **kwargs)
#     174 else:
# --> 175     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/engine/predictor.py:269, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     267 with profilers[2]:
#     268     self.results = self.postprocess(preds, im, im0s)
# --> 269 self.run_callbacks("on_predict_postprocess_end")
#     271 # Visualize, save, write results
#     272 n = len(im0s)
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/engine/predictor.py:406, in BasePredictor.run_callbacks(self, event)
#     404 """Runs all registered callbacks for a specific event."""
#     405 for callback in self.callbacks.get(event, []):
# --> 406     callback(self)
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/trackers/track.py:81, in on_predict_postprocess_end(predictor, persist)
#      79 if len(det) == 0:
#      80     continue
# ---> 81 tracks = tracker.update(det, result.orig_img)
#      82 if len(tracks) == 0:
#      83     continue
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/trackers/byte_tracker.py:337, in BYTETracker.update(self, results, img)
#     334     STrack.multi_gmc(strack_pool, warp)
#     335     STrack.multi_gmc(unconfirmed, warp)
# --> 337 dists = self.get_dists(strack_pool, detections)
#     338 matches, u_track, u_detection = matching.linear_assignment(dists, thresh=self.args.match_thresh)
#     340 for itracked, idet in matches:
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/trackers/bot_sort.py:216, in BOTSORT.get_dists(self, tracks, detections)
#     213 dists = matching.iou_distance(tracks, detections)
#     214 dists_mask = dists > self.proximity_thresh
# --> 216 if self.args.fuse_score:
#     217     dists = matching.fuse_score(dists, detections)
#     219 if self.args.with_reid and self.encoder is not None:
#
# File ~/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/utils/__init__.py:288, in IterableSimpleNamespace.__getattr__(self, attr)
#     286 """Custom attribute access error message with helpful information."""
#     287 name = self.__class__.__name__
# --> 288 raise AttributeError(
#     289     f"""
#     290     '{name}' object has no attribute '{attr}'. This may be caused by a modified or out of date ultralytics
#     291     'default.yaml' file.\nPlease update your code with 'pip install -U ultralytics' and if necessary replace
#     292     {DEFAULT_CFG_PATH} with the latest version from
#     293     https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml
#     294     """
#     295 )
#
# AttributeError:
#             'IterableSimpleNamespace' object has no attribute 'fuse_score'. This may be caused by a modified or out of date ultralytics
#             'default.yaml' file.
# Please update your code with 'pip install -U ultralytics' and if necessary replace
#             /home/serg/VKR_25_YOLOv7/venv/lib/python3.11/site-packages/ultralytics/cfg/default.yaml with the latest version from
#             https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/default.yaml

# %% [markdown]
# Трекинг лишь на класс птица:

# %%
import cv2
from ultralytics import YOLO
import random


def draw_bounding_boxes_without_id(frame, results):
    boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
    classes = results[0].boxes.cls.cpu().numpy().astype(int)

    for box, clss in zip(boxes, classes):
        # Generate a random color for each object based on its ID
        if clss != 0:
            random.seed(int(clss)+8)
            color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
            
            cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3],), color, 2)
            cv2.putText(
                frame,
                f"{model.model.names[clss]}",
                (box[0], box[1]),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (50, 255, 50),
                2,
            )
    return frame


def process_video_with_tracking(model, input_video_path, show_video=True, save_video=False, output_video_path="output_video.mp4"):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    if not cap.isOpened():
        raise Exception("Error: Could not open video file.")

    # Get input video frame rate and dimensions
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define the output video writer
    if save_video:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        results = model.track(frame, iou=0.4, conf=0.5, persist=True, imgsz=608, verbose=False, tracker="bytetrack.yaml", classes=0)
        results_detect = model_detect.predict(frame, iou=0.4, conf=0.5, imgsz=608, verbose=False)
    
        if results[0].boxes.id != None: # this will ensure that id is not None -> exist tracks
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
            ids = results[0].boxes.id.cpu().numpy().astype(int)

            for box, id in zip(boxes, ids):
                # Generate a random color for each object based on its ID
                random.seed(int(id))
                color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
                
                cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3],), color, 2)
                cv2.putText(
                    frame,
                    f"Id {id}",
                    (box[0], box[1]),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.70,
                    (0, 255, 255),
                    2,
                )

        if results_detect[0].boxes != None:
            draw_bounding_boxes_without_id(frame, results_detect)
            
        
        if save_video:
            out.write(frame)

        if show_video:
            frame = cv2.resize(frame, (0, 0), fx=0.75, fy=0.75)
            cv2.imshow("frame", frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    # Release the input video capture and output video writer
    cap.release()
    if save_video:
        out.release()

    # Close all OpenCV windows
    cv2.destroyAllWindows()
    return results_detect, results

# Example usage:
model = YOLO('runs/detect/train/weights/best.pt')
model_detect = YOLO('runs/detect/train/weights/best.pt')
model.fuse()
model_detect.fuse()
results_detect, results = process_video_with_tracking(model, "test.mp4", show_video=True, save_video=False, output_video_path="output_video.mp4")
# Out:
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
